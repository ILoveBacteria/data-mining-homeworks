# %%
import pandas as pd

# %% [markdown]
# # Data values

# %%
df = pd.read_csv('Teen_Mental_Health_Dataset.csv')
df
# Out:
#       age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0      14    male                       7.9      Instagram          7.4
# 1      19  female                       1.9         TikTok          8.0
# 2      17  female                       1.3      Instagram          7.6
# 3      15    male                       7.4         TikTok          6.9
# 4      15  female                       4.7           Both          4.9
# ...   ...     ...                       ...            ...          ...
# 1195   18  female                       6.8      Instagram          6.6
# 1196   16    male                       2.3           Both          8.0
# 1197   14  female                       1.7           Both          8.7
# 1198   15    male                       3.9           Both          8.5
# 1199   16  female                       4.7         TikTok          6.5
#
#       screen_time_before_sleep  academic_performance  physical_activity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1200 non-null   int64
#  1   gender                    1200 non-null   str
#  2   daily_social_media_hours  1200 non-null   float64
#  3   platform_usage            1200 non-null   str
#  4   sleep_hours               1200 non-null   float64
#  5   screen_time_before_sleep  1200 non-null   float64
#  6   academic_performance      1200 non-null   float64
#  7   physical_activity         1200 non-null   float64
#  8   social_interaction_level  1200 non-null   str
#  9   stress_level              1200 non-null   int64
#  10  anxiety_level             1200 non-null   int64
#  11  addiction_level           1200 non-null   int64
#  12  depression_label          1200 non-null   int64
# dtypes: float64(5), int64(5), str(3)
# memory usage: 122.0 KB

# %%
df['age'].describe()
# Out:
# count    1200.000000
# mean       15.928333
# std         2.021947
# min        13.000000
# 25%        14.000000
# 50%        16.000000
# 75%        18.000000
# max        19.000000
# Name: age, dtype: float64

# %%
df['gender'].unique()
# Out:
# <StringArray>
# ['male', 'female']
# Length: 2, dtype: str

# %%
df['daily_social_media_hours'].describe()
# Out:
# count    1200.000000
# mean        4.536667
# std         2.029599
# min         1.000000
# 25%         2.800000
# 50%         4.500000
# 75%         6.300000
# max         8.000000
# Name: daily_social_media_hours, dtype: float64

# %%
df['platform_usage'].unique()
# Out:
# <StringArray>
# ['Instagram', 'TikTok', 'Both']
# Length: 3, dtype: str

# %%
df['sleep_hours'].describe()
# Out:
# count    1200.000000
# mean        6.449417
# std         1.442677
# min         4.000000
# 25%         5.200000
# 50%         6.500000
# 75%         7.600000
# max         9.000000
# Name: sleep_hours, dtype: float64

# %%
df['screen_time_before_sleep'].describe()
# Out:
# count    1200.000000
# mean        1.740333
# std         0.716660
# min         0.500000
# 25%         1.100000
# 50%         1.800000
# 75%         2.400000
# max         3.000000
# Name: screen_time_before_sleep, dtype: float64

# %%
df['academic_performance'].describe()
# Out:
# count    1200.000000
# mean        2.990383
# std         0.576758
# min         2.000000
# 25%         2.500000
# 50%         2.990000
# 75%         3.480000
# max         4.000000
# Name: academic_performance, dtype: float64

# %%
df['physical_activity'].describe()
# Out:
# count    1200.000000
# mean        1.014500
# std         0.582185
# min         0.000000
# 25%         0.500000
# 50%         1.000000
# 75%         1.500000
# max         2.000000
# Name: physical_activity, dtype: float64

# %%
df['social_interaction_level'].unique()
# Out:
# <StringArray>
# ['low', 'high', 'medium']
# Length: 3, dtype: str

# %%
df['stress_level'].unique()
# Out:
# array([ 2,  8,  1,  3,  6,  5,  4, 10,  9,  7])

# %%
df['anxiety_level'].unique()
# Out:
# array([ 2,  1,  4,  7,  5, 10,  8,  9,  6,  3])

# %%
df['addiction_level'].unique()
# Out:
# array([ 1, 10,  2,  9,  7,  5,  4,  8,  6,  3])

# %%
df['depression_label'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# # Distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Optional: Better plot style
sns.set_theme(style="whitegrid")

# Columns to plot
columns = [
    "stress_level",
    "sleep_hours",
    "daily_social_media_hours",
    "age"
]

# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

# Plot each column
for ax, col in zip(axes, columns):
    sns.histplot(
        data=df,
        x=col,
        bins=20,
        kde=True,
        color="steelblue",
        edgecolor="black",
        ax=ax
    )
    ax.set_title(f"Distribution of {col}")
    ax.set_xlabel(col)
    ax.set_ylabel("Count")

plt.tight_layout()
plt.show()

# %%
# Optional: Better plot style
sns.set_theme(style="whitegrid")

# Categorical columns
columns = [
    "platform_usage",
    "social_interaction_level"
]

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot count bars
for ax, col in zip(axes, columns):
    sns.countplot(
        data=df,
        x=col,
        order=df[col].value_counts().index,  # Sort by frequency
        edgecolor="black",
        ax=ax
    )

    ax.set_title(f"Distribution of {col}")
    ax.set_xlabel(col)
    ax.set_ylabel("Count")
    ax.tick_params(axis='x', rotation=30)

plt.tight_layout()
plt.show()

# %%
# Count each class
counts = df["depression_label"].value_counts()

# Create pie chart

plt.pie(
    counts,
    labels=counts.index,
    autopct='%1.1f%%',
    startangle=90,
    explode=[0.05] * len(counts),   # Slightly separate slices
    shadow=True
)

plt.title("Distribution of Depression Labels")
plt.axis("equal")  # Make the pie chart circular

plt.show()

# %% [markdown]
# # String to numerical value

# %%
# Convert categorical columns to numerical

df["gender"] = df["gender"].map({
    "male": 0,
    "female": 1
})

df["platform_usage"] = df["platform_usage"].map({
    "Instagram": 0,
    "TikTok": 1,
    "Both": 2
})

df["social_interaction_level"] = df["social_interaction_level"].map({
    "low": 0,
    "medium": 1,
    "high": 2
})

# %%
df
# Out:
#       age  gender  daily_social_media_hours  platform_usage  sleep_hours  \
# 0      14       0                       7.9               0          7.4
# 1      19       1                       1.9               1          8.0
# 2      17       1                       1.3               0          7.6
# 3      15       0                       7.4               1          6.9
# 4      15       1                       4.7               2          4.9
# ...   ...     ...                       ...             ...          ...
# 1195   18       1                       6.8               0          6.6
# 1196   16       0                       2.3               2          8.0
# 1197   14       1                       1.7               2          8.7
# 1198   15       0                       3.9               2          8.5
# 1199   16       1                       4.7               1          6.5
#
#       screen_time_before_sleep  academic_performance  physical_activity  \
# ...

# %%
# Compute correlation matrix
corr = df.corr(numeric_only=True)

# Plot
plt.figure(figsize=(12, 10))
sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0,
    square=True,
    linewidths=0.5,
    cbar_kws={"shrink": 0.8}
)

plt.title("Correlation Heatmap", fontsize=16)
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Normalization

# %%
df
# Out:
#       age  gender  daily_social_media_hours  platform_usage  sleep_hours  \
# 0      14       0                       7.9               0          7.4
# 1      19       1                       1.9               1          8.0
# 2      17       1                       1.3               0          7.6
# 3      15       0                       7.4               1          6.9
# 4      15       1                       4.7               2          4.9
# ...   ...     ...                       ...             ...          ...
# 1195   18       1                       6.8               0          6.6
# 1196   16       0                       2.3               2          8.0
# 1197   14       1                       1.7               2          8.7
# 1198   15       0                       3.9               2          8.5
# 1199   16       1                       4.7               1          6.5
#
#       screen_time_before_sleep  academic_performance  physical_activity  \
# ...

# %%
y_column = 'depression_label'
X = df[list(set(df.columns) - {y_column})]
y = df[y_column]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(X)
X_normalize = scaler.transform(X)
X_normalize
# Out:
# array([[0.75      , 0.96      , 0.11111111, ..., 0.        , 0.11111111,
#         0.        ],
#        [0.4       , 0.96      , 0.        , ..., 0.5       , 0.77777778,
#         1.        ],
#        [0.        , 0.        , 0.33333333, ..., 0.        , 0.11111111,
#         0.11111111],
#        ...,
#        [0.4       , 0.08      , 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.3       , 0.64      , 0.88888889, ..., 1.        , 0.66666667,
#         0.88888889],
#        [0.45      , 0.2       , 0.66666667, ..., 0.5       , 0.44444444,
#         0.22222222]], shape=(1200, 12))

# %% [markdown]
# # Imbalance data

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X_normalize, y, test_size=0.2, stratify=y, random_state=42)

# %%
from imblearn.combine import SMOTETomek

smote_tomek = SMOTETomek(random_state=42)

X_train_balanced, y_train_balanced = smote_tomek.fit_resample(X_train, y_train)

print(y_train.value_counts())
print(y_train_balanced.value_counts())
# Out:
# depression_label
# 0    935
# 1     25
# Name: count, dtype: int64
# depression_label
# 0    935
# 1    935
# Name: count, dtype: int64

# %% [markdown]
# # Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    confusion_matrix,
    ConfusionMatrixDisplay,
    classification_report,
    precision_score,
    recall_score,
    f1_score
)

# %%
model_log = LogisticRegression(random_state=42, max_iter=1000)
model_log.fit(X_train, y_train)

y_pred = model_log.predict(X_test)


print(f"Precision : {precision_score(y_test, y_pred):.4f}")
print(f"Recall    : {recall_score(y_test, y_pred):.4f}")
print(f"F1-score  : {f1_score(y_test, y_pred):.4f}")

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Precision : 0.0000
# Recall    : 0.0000
# F1-score  : 0.0000
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       234
#            1       0.00      0.00      0.00         6
#
#     accuracy                           0.97       240
#    macro avg       0.49      0.50      0.49       240
# weighted avg       0.95      0.97      0.96       240
# /home/moein/Documents/data-mining-homeworks/.venv/lib/python3.14/site-packages/sklearn/metrics/_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %%
model_log = LogisticRegression(random_state=42, max_iter=1000, class_weight="balanced")
model_log.fit(X_train, y_train)

y_pred = model_log.predict(X_test)


print(f"Precision : {precision_score(y_test, y_pred):.4f}")
print(f"Recall    : {recall_score(y_test, y_pred):.4f}")
print(f"F1-score  : {f1_score(y_test, y_pred):.4f}")

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Precision : 0.3529
# Recall    : 1.0000
# F1-score  : 0.5217
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98       234
#            1       0.35      1.00      0.52         6
#
#     accuracy                           0.95       240
#    macro avg       0.68      0.98      0.75       240
# weighted avg       0.98      0.95      0.96       240

# %%
model_log = LogisticRegression(random_state=42, max_iter=1000)
model_log.fit(X_train_balanced, y_train_balanced)

y_pred = model_log.predict(X_test)


print(f"Precision : {precision_score(y_test, y_pred):.4f}")
print(f"Recall    : {recall_score(y_test, y_pred):.4f}")
print(f"F1-score  : {f1_score(y_test, y_pred):.4f}")

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Precision : 0.4000
# Recall    : 1.0000
# F1-score  : 0.5714
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       234
#            1       0.40      1.00      0.57         6
#
#     accuracy                           0.96       240
#    macro avg       0.70      0.98      0.78       240
# weighted avg       0.98      0.96      0.97       240

# %%
importance_lg = (
    pd.DataFrame({
        "Feature": X.columns,
        "Coefficient": model_log.coef_[0],
        "Absolute Coefficient": abs(model_log.coef_[0])
    })
    .sort_values("Absolute Coefficient", ascending=False)
)

plt.figure(figsize=(10, 6))
sns.barplot(
    data=importance_lg,
    x="Absolute Coefficient",
    y="Feature"
)
plt.title("Feature Importance (Absolute Logistic Regression Coefficients)")
plt.xlabel("Absolute Coefficient")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=model_log.classes_,
    yticklabels=model_log.classes_
)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

print(f"Precision : {precision_score(y_test, y_pred):.4f}")
print(f"Recall    : {recall_score(y_test, y_pred):.4f}")
print(f"F1-score  : {f1_score(y_test, y_pred):.4f}")

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Precision : 0.4000
# Recall    : 1.0000
# F1-score  : 0.5714
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       234
#            1       0.40      1.00      0.57         6
#
#     accuracy                           0.96       240
#    macro avg       0.70      0.98      0.78       240
# weighted avg       0.98      0.96      0.97       240

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

results = []

best_k = None
best_f1 = -1
best_model_knn = None

for k in range(3, 12):
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(X_train_balanced, y_train_balanced)

    y_pred = model.predict(X_test)
    f1 = f1_score(y_test, y_pred)

    results.append({"k": k, "F1-score": f1})

    if f1 > best_f1:
        best_f1 = f1
        best_k = k
        best_model_knn = model

results_df = pd.DataFrame(results)

print(results_df)
print(f"\nBest k: {best_k}")
print(f"Best F1-score: {best_f1:.4f}")
# Out:
#     k  F1-score
# 0   3  0.357143
# 1   4  0.357143
# 2   5  0.285714
# 3   6  0.303030
# 4   7  0.277778
# 5   8  0.277778
# 6   9  0.263158
# 7  10  0.263158
# 8  11  0.238095
#
# Best k: 3
# Best F1-score: 0.3571

# %%
y_pred = best_model_knn.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=best_model_knn.classes_,
    yticklabels=best_model_knn.classes_
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title(f"Confusion Matrix (k={best_k})")
plt.tight_layout()
plt.show()

print(f"Precision : {precision_score(y_test, y_pred):.4f}")
print(f"Recall    : {recall_score(y_test, y_pred):.4f}")
print(f"F1-score  : {f1_score(y_test, y_pred):.4f}")

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Precision : 0.2273
# Recall    : 0.8333
# F1-score  : 0.3571
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96       234
#            1       0.23      0.83      0.36         6
#
#     accuracy                           0.93       240
#    macro avg       0.61      0.88      0.66       240
# weighted avg       0.98      0.93      0.95       240

# %% [markdown]
# # Tree

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

model_tree = DecisionTreeClassifier(
    max_depth=4,
    random_state=42
)

model_tree.fit(X_train_balanced, y_train_balanced)

y_pred = model_tree.predict(X_test)

plt.figure(figsize=(20, 10))
plot_tree(
    model_tree,
    feature_names=X.columns,
    class_names=["0", "1"],
    filled=True,
    rounded=True,
    fontsize=10
)
plt.title("Decision Tree (max_depth=4)")
plt.show()

# %%
importance_tree = (
    pd.DataFrame({
        "Feature": X.columns,
        "Importance": model_tree.feature_importances_
    })
    .sort_values("Importance", ascending=False)
)

plt.figure(figsize=(10, 6))
sns.barplot(
    data=importance_tree,
    x="Importance",
    y="Feature"
)
plt.title("Feature Importance")
plt.tight_layout()
plt.show()


print("Top Features:")
print(importance_tree)
# Out:
# Top Features:
#                      Feature  Importance
# 7                sleep_hours    0.478714
# 10              stress_level    0.308751
# 2              anxiety_level    0.156394
# 8   daily_social_media_hours    0.054109
# 1   screen_time_before_sleep    0.001070
# 3       academic_performance    0.000963
# 0          physical_activity    0.000000
# 4                        age    0.000000
# 6   social_interaction_level    0.000000
# 5                     gender    0.000000
# 9             platform_usage    0.000000
# 11           addiction_level    0.000000

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=model_tree.classes_,
    yticklabels=model_tree.classes_
)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

print(f"Precision : {precision_score(y_test, y_pred):.4f}")
print(f"Recall    : {recall_score(y_test, y_pred):.4f}")
print(f"F1-score  : {f1_score(y_test, y_pred):.4f}")

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Precision : 1.0000
# Recall    : 1.0000
# F1-score  : 1.0000
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       234
#            1       1.00      1.00      1.00         6
#
#     accuracy                           1.00       240
#    macro avg       1.00      1.00      1.00       240
# weighted avg       1.00      1.00      1.00       240

# %%
train_f1 = []
test_f1 = []
depths = range(1, 10)

for depth in depths:
    model = DecisionTreeClassifier(
        max_depth=depth,
        random_state=42
    )

    model.fit(X_train_balanced, y_train_balanced)

    y_train_pred = model.predict(X_train_balanced)
    y_test_pred = model.predict(X_test)

    train_f1.append(f1_score(y_train_balanced, y_train_pred))
    test_f1.append(f1_score(y_test, y_test_pred))

plt.figure(figsize=(8, 5))

plt.plot(
    depths,
    train_f1,
    marker="o",
    linewidth=2,
    label="Train F1-score"
)

plt.plot(
    depths,
    test_f1,
    marker="s",
    linewidth=2,
    label="Test F1-score"
)

plt.xticks(depths)
plt.xlabel("max_depth")
plt.ylabel("F1-score")
plt.title("Decision Tree Performance vs. Tree Depth")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # SVM

# %% [markdown]
# By default does not compute the probability. I add `probability=True,` to it

# %%
from sklearn.svm import SVC
from sklearn.decomposition import PCA

linear_svm = SVC(kernel="linear", probability=True, random_state=42)
rbf_svm = SVC(kernel="rbf", probability=True, random_state=42)

linear_svm.fit(X_train_balanced, y_train_balanced)
rbf_svm.fit(X_train_balanced, y_train_balanced)

y_pred_linear = linear_svm.predict(X_test)
y_pred_rbf = rbf_svm.predict(X_test)
# Out:
# /home/moein/Documents/data-mining-homeworks/.venv/lib/python3.14/site-packages/sklearn/svm/_base.py:239: FutureWarning: The `probability` parameter was deprecated in 1.9 and will be removed in version 1.11. Use `CalibratedClassifierCV(SVC(), ensemble=False)` instead of `SVC(probability=True)`
#   warnings.warn(
# /home/moein/Documents/data-mining-homeworks/.venv/lib/python3.14/site-packages/sklearn/svm/_base.py:239: FutureWarning: The `probability` parameter was deprecated in 1.9 and will be removed in version 1.11. Use `CalibratedClassifierCV(SVC(), ensemble=False)` instead of `SVC(probability=True)`
#   warnings.warn(

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.heatmap(
    confusion_matrix(y_test, y_pred_linear),
    annot=True,
    fmt="d",
    cmap="Blues",
    ax=axes[0]
)
axes[0].set_title("Linear SVM")
axes[0].set_xlabel("Predicted")
axes[0].set_ylabel("Actual")

sns.heatmap(
    confusion_matrix(y_test, y_pred_rbf),
    annot=True,
    fmt="d",
    cmap="Blues",
    ax=axes[1]
)
axes[1].set_title("RBF SVM")
axes[1].set_xlabel("Predicted")
axes[1].set_ylabel("Actual")

plt.tight_layout()
plt.show()


results = pd.DataFrame({
    "Model": ["Linear SVM", "RBF SVM"],
    "Precision": [
        precision_score(y_test, y_pred_linear),
        precision_score(y_test, y_pred_rbf)
    ],
    "Recall": [
        recall_score(y_test, y_pred_linear),
        recall_score(y_test, y_pred_rbf)
    ],
    "F1-score": [
        f1_score(y_test, y_pred_linear),
        f1_score(y_test, y_pred_rbf)
    ]
})

print(results)

print("\nLinear SVM Classification Report\n")
print(classification_report(y_test, y_pred_linear))

print("\nRBF SVM Classification Report\n")
print(classification_report(y_test, y_pred_rbf))
# Out:
#         Model  Precision    Recall  F1-score
# 0  Linear SVM        0.4  1.000000  0.571429
# 1     RBF SVM        1.0  0.666667  0.800000
#
# Linear SVM Classification Report
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       234
#            1       0.40      1.00      0.57         6
#
#     accuracy                           0.96       240
#    macro avg       0.70      0.98      0.78       240
# weighted avg       0.98      0.96      0.97       240
#
#
# RBF SVM Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       234
#            1       1.00      0.67      0.80         6
#
#     accuracy                           0.99       240
#    macro avg       1.00      0.83      0.90       240
# weighted avg       0.99      0.99      0.99       240

# %% [markdown]
# PCA requires variables be in Standardize form. So rescale all features...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

scaler_std = StandardScaler()

X_standard = scaler_std.fit_transform(X)

X_train_std, X_test_std, y_train_std, y_test_std = train_test_split(
    X_standard,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

smote_tomek_std = SMOTETomek(random_state=42)

X_train_std_balanced, y_train_std_balanced = smote_tomek_std.fit_resample(
    X_train_std,
    y_train_std
)

pca = PCA(n_components=2)

X_train_std_pca = pca.fit_transform(X_train_std_balanced)
X_test_std_pca = pca.transform(X_test_std)

linear_svm_pca = SVC(kernel="linear", random_state=42)
rbf_svm_pca = SVC(kernel="rbf", random_state=42)

linear_svm_pca.fit(X_train_std_pca, y_train_std_balanced)
rbf_svm_pca.fit(X_train_std_pca, y_train_std_balanced)

x_min = X_train_std_pca[:, 0].min() - 1
x_max = X_train_std_pca[:, 0].max() + 1
y_min = X_train_std_pca[:, 1].min() - 1
y_max = X_train_std_pca[:, 1].max() + 1

xx, yy = np.meshgrid(
    np.linspace(x_min, x_max, 500),
    np.linspace(y_min, y_max, 500)
)

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

for ax, model, title in zip(
    axes,
    [linear_svm_pca, rbf_svm_pca],
    ["Linear SVM", "RBF SVM"]
):
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    ax.contourf(xx, yy, Z, alpha=0.3, cmap="coolwarm")

    ax.scatter(
        X_test_std_pca[:, 0],
        X_test_std_pca[:, 1],
        c=y_test_std,
        cmap="coolwarm",
        edgecolors="k",
        s=40
    )

    ax.set_title(title)
    ax.set_xlabel("Principal Component 1")
    ax.set_ylabel("Principal Component 2")

plt.tight_layout()
plt.show()

# %% [markdown]
# Also check the decision boundaries of LogisticRegression

# %%
pca = PCA(n_components=2)

X_train_std_pca = pca.fit_transform(X_train_std_balanced)
X_test_std_pca = pca.transform(X_test_std)

logistic_pca = LogisticRegression(
    random_state=42,
    max_iter=1000
)

logistic_pca.fit(X_train_std_pca, y_train_std_balanced)

x_min = X_train_std_pca[:, 0].min() - 1
x_max = X_train_std_pca[:, 0].max() + 1
y_min = X_train_std_pca[:, 1].min() - 1
y_max = X_train_std_pca[:, 1].max() + 1

xx, yy = np.meshgrid(
    np.linspace(x_min, x_max, 500),
    np.linspace(y_min, y_max, 500)
)

Z = logistic_pca.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.figure(figsize=(8, 6))

plt.contourf(xx, yy, Z, alpha=0.3, cmap="coolwarm")

plt.scatter(
    X_test_std_pca[:, 0],
    X_test_std_pca[:, 1],
    c=y_test_std,
    cmap="coolwarm",
    edgecolors="k",
    s=40
)

plt.title("Logistic Regression Decision Boundary (PCA)")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf_model.fit(X_train_balanced, y_train_balanced)

importance_rf = (
    pd.DataFrame({
        "Feature": X.columns,
        "Importance": rf_model.feature_importances_
    })
    .sort_values("Importance", ascending=False)
)

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.barplot(
    data=importance_tree,
    x="Importance",
    y="Feature",
    ax=axes[0]
)
axes[0].set_title("Decision Tree Feature Importance")

sns.barplot(
    data=importance_rf,
    x="Importance",
    y="Feature",
    ax=axes[1]
)
axes[1].set_title("Random Forest Feature Importance")

plt.tight_layout()
plt.show()

from sklearn.metrics import (
    confusion_matrix,
    precision_score,
    recall_score,
    f1_score,
    classification_report
)

y_pred_rf = rf_model.predict(X_test)

print(f"Precision : {precision_score(y_test, y_pred_rf):.4f}")
print(f"Recall    : {recall_score(y_test, y_pred_rf):.4f}")
print(f"F1-score  : {f1_score(y_test, y_pred_rf):.4f}")

print(classification_report(y_test, y_pred_rf))

plt.figure(figsize=(6,5))
sns.heatmap(
    confusion_matrix(y_test, y_pred_rf),
    annot=True,
    fmt="d",
    cmap="Blues"
)
plt.title("Random Forest Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()
# Out:
# Precision : 1.0000
# Recall    : 0.6667
# F1-score  : 0.8000
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       234
#            1       1.00      0.67      0.80         6
#
#     accuracy                           0.99       240
#    macro avg       1.00      0.83      0.90       240
# weighted avg       0.99      0.99      0.99       240

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier, plot_tree
from sklearn.model_selection import GridSearchCV

param_grid = {
    "max_depth": [3, 5, 7],
    "learning_rate": [0.01, 0.1, 0.2],
    "n_estimators": [50, 100, 200]
}

xgb = XGBClassifier(
    objective="binary:logistic",
    eval_metric="logloss",
    random_state=42
)

grid = GridSearchCV(
    estimator=xgb,
    param_grid=param_grid,
    scoring="f1_macro",
    cv=5,
    n_jobs=-1,
    verbose=1
)

grid.fit(X_train_balanced, y_train_balanced)

print("Best Parameters:")
print(grid.best_params_)

print(f"\nBest CV F1_macro: {grid.best_score_:.4f}")

best_model_xgb = grid.best_estimator_

y_pred = best_model_xgb.predict(X_test)

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

print(f"Precision : {precision_score(y_test, y_pred):.4f}")
print(f"Recall    : {recall_score(y_test, y_pred):.4f}")
print(f"F1-score  : {f1_score(y_test, y_pred):.4f}")

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)
plt.title("XGBoost Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best Parameters:
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}
#
# Best CV F1_macro: 0.9973
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       234
#            1       1.00      1.00      1.00         6
#
#     accuracy                           1.00       240
#    macro avg       1.00      1.00      1.00       240
# weighted avg       1.00      1.00      1.00       240
#
# Precision : 1.0000
# Recall    : 1.0000
# F1-score  : 1.0000

# %% [markdown]
# # Model evaluation and selection

# %%
from sklearn.metrics import roc_curve, roc_auc_score, accuracy_score

models = {
    "Logistic Regression": model_log,
    "KNN": best_model_knn,
    "Decision Tree": model_tree,
    "Linear SVM": linear_svm,
    "RBF SVM": rbf_svm,
    "Random Forest": rf_model,
    "XGBoost": best_model_xgb
}

results = []

plt.figure(figsize=(8, 6))

for name, model in models.items():

    y_pred = model.predict(X_test)
    y_score = model.predict_proba(X_test)[:, 1]

    fpr, tpr, _ = roc_curve(y_test, y_score)
    auc = roc_auc_score(y_test, y_score)

    plt.plot(fpr, tpr, linewidth=2, label=f"{name} (AUC={auc:.3f})")

    results.append({
        "Model": name,
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "F1-score": f1_score(y_test, y_pred),
        "AUC": auc
    })

plt.plot([0, 1], [0, 1], "k--")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

results_df = pd.DataFrame(results)

print(results_df.sort_values("F1-score", ascending=False))
# Out:
#                  Model  Accuracy  Precision    Recall  F1-score       AUC
# 2        Decision Tree  1.000000   1.000000  1.000000  1.000000  1.000000
# 6              XGBoost  1.000000   1.000000  1.000000  1.000000  1.000000
# 4              RBF SVM  0.991667   1.000000  0.666667  0.800000  0.987179
# 5        Random Forest  0.991667   1.000000  0.666667  0.800000  1.000000
# 0  Logistic Regression  0.962500   0.400000  1.000000  0.571429  0.994302
# 3           Linear SVM  0.962500   0.400000  1.000000  0.571429  0.989316
# 1                  KNN  0.925000   0.227273  0.833333  0.357143  0.886752

# %%
metrics = ["Accuracy", "Precision", "Recall", "F1-score", "AUC"]

fig, axes = plt.subplots(2, 3, figsize=(16, 10))
axes = axes.flatten()

for i, metric in enumerate(metrics):
    sns.barplot(
        data=results_df,
        x="Model",
        y=metric,
        ax=axes[i]
    )

    axes[i].set_title(metric)
    axes[i].tick_params(axis="x", rotation=30)

axes[-1].axis("off")

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import precision_score, recall_score

models = {
    "Decision Tree": model_tree,
    "Random Forest": rf_model,
    "XGBoost": best_model_xgb
}

thresholds = np.linspace(0.0, 1.0, 101)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for ax, (name, model) in zip(axes, models.items()):

    y_prob = model.predict_proba(X_test)[:, 1]

    precisions = []
    recalls = []

    for threshold in thresholds:
        y_pred = (y_prob >= threshold).astype(int)

        precisions.append(
            precision_score(y_test, y_pred, zero_division=0)
        )

        recalls.append(
            recall_score(y_test, y_pred)
        )

    ax.plot(thresholds, precisions, label="Precision")
    ax.plot(thresholds, recalls, label="Recall")

    ax.set_title(name)
    ax.set_xlabel("Threshold")
    ax.set_ylabel("Score")
    ax.set_ylim(0, 1.05)
    ax.grid(True)
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Feature selection

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_selection import mutual_info_classif
from sklearn.preprocessing import MinMaxScaler

information_gain = mutual_info_classif(
    X,
    y,
    random_state=42
)

fisher_scores = []

for feature in X.columns:
    x0 = X.loc[y == 0, feature]
    x1 = X.loc[y == 1, feature]

    score = (x0.mean() - x1.mean()) ** 2 / (x0.var() + x1.var() + 1e-10)
    fisher_scores.append(score)

importance_xgb = pd.DataFrame({
    "Feature": X.columns,
    "Importance": best_model_xgb.feature_importances_
})

comparison = pd.DataFrame({
    "Feature": X.columns,
    "Information Gain": information_gain,
    "Fisher Score": fisher_scores,
    "Decision Tree": importance_tree.set_index("Feature").loc[X.columns, "Importance"].values,
    "Random Forest": importance_rf.set_index("Feature").loc[X.columns, "Importance"].values,
    "XGBoost": importance_xgb.set_index("Feature").loc[X.columns, "Importance"].values,
    "Logistic": importance_lg.set_index("Feature").loc[X.columns, "Absolute Coefficient"].values,

})

scaler = MinMaxScaler()

numeric_cols = comparison.columns[1:]
comparison[numeric_cols] = comparison[numeric_cols].astype(np.float64)
comparison[numeric_cols] = scaler.fit_transform(comparison[numeric_cols])

comparison["Consensus"] = comparison.iloc[:, 1:].mean(axis=1)

comparison = comparison.sort_values("Consensus", ascending=False)

print(comparison)

plt.figure(figsize=(10, 8))

sns.heatmap(
    comparison.set_index("Feature"),
    annot=True,
    cmap="YlGnBu",
    linewidths=0.5
)

plt.title("Normalized Feature Importance Comparison")
plt.tight_layout()
plt.show()

plt.figure(figsize=(10,6))

sns.barplot(
    data=comparison,
    x="Consensus",
    y="Feature"
)

plt.title("Consensus Feature Importance")
plt.tight_layout()
plt.show()
# Out:
#                      Feature  Information Gain  Fisher Score  Decision Tree  \
# 7                sleep_hours          0.927559      1.000000       1.000000
# 10              stress_level          0.972358      0.782078       0.644960
# 2              anxiety_level          1.000000      0.798253       0.326696
# 8   daily_social_media_hours          0.827878      0.777550       0.113029
# 11           addiction_level          0.260788      0.002819       0.000000
# 9             platform_usage          0.121005      0.000122       0.000000
# 3       academic_performance          0.000000      0.000000       0.002011
# 5                     gender          0.000000      0.006066       0.000000
# 0          physical_activity          0.000000      0.004923       0.000000
# 6   social_interaction_level          0.000000      0.003193       0.000000
# 1   screen_time_before_sleep          0.000000      0.003934       0.002234
# ...
